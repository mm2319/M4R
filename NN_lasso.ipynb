# %%
from Network import FeedForwardNetwork
from NN_deri_Lorenz import train_lorenz, obtain_lorenz_data
from NN_deri_two_compart import train_twocompart, obtain_twocompart_data
from NN_deri_nonlinear import train_nonlinear,obtain_nonlinear_data
from scipy.integrate import odeint
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
import pandas
from lorenz import create_data_lorenz
from non_linear import create_data_nonlinear
from two_compartment import create_data_twocompart
from Derivative_Data_Lorenz import obtain_train_data_Lorenz
from Derivative_Data_NonLinear import obtain_train_data_NonLinear
from Derivative_Data_Two_Compart import obtain_train_data_Two_compart
from Bayesian_Regression_Disc_Spike_and_Slab import Bayesian_regression_disc_spike_slab
from Bayesian_Regression_Cont_Spike_and_Slab import Bayesian_regression_conti_spike_slab
from Bayesian_Regression_SS_Selection_2 import Bayesian_regression_SS_Selction
import os
network_twocompart = FeedForwardNetwork(2)
network_nonlinear = FeedForwardNetwork(2)
network_lorenz = FeedForwardNetwork(3)
T, Y = create_data_lorenz(p=0.)
network_lorenz.load_weights('./NN_lorenz_checkpoints_000/my_checkpoint')
T, Y = create_data_nonlinear(p=0.)
network_nonlinear.load_weights('./NN_nonlinear_checkpoints_000/my_checkpoint')
T, Y = create_data_twocompart(p=0.)
network_twocompart.load_weights('./NN_twocompart_checkpoints_000/my_checkpoint')

T, Y = create_data_twocompart(p=0.)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)



T, Y = create_data_nonlinear(p=0.)
model = FeedForwardNetwork(2)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)



T, Y = create_data_lorenz(p=0.)
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_000_tc_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_000_tc_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)
clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_000_nl_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_000_nl_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_3 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)
clf_3.fit(x_1_train, y_3_train)


np.save('nn_ls_000_lr_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_000_lr_2',np.array(list(clf_2.coef_)))
np.save('nn_ls_000_lr_3',np.array(list(clf_3.coef_)))

# %%
network_twocompart = FeedForwardNetwork(2)
network_nonlinear = FeedForwardNetwork(2)
network_lorenz = FeedForwardNetwork(3)
T, Y = create_data_lorenz(p=0.01)
network_lorenz.load_weights('./NN_lorenz_checkpoints_001/my_checkpoint')
T, Y = create_data_nonlinear(p=0.01)
network_nonlinear.load_weights('./NN_nonlinear_checkpoints_001/my_checkpoint')
T, Y = create_data_twocompart(p=0.01)
network_twocompart.load_weights('./NN_twocompart_checkpoints_001/my_checkpoint')

T, Y = create_data_twocompart(p=0.01)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)



T, Y = create_data_nonlinear(p=0.01)
model = FeedForwardNetwork(2)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)



T, Y = create_data_lorenz(p=0.01)
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_001_tc_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_001_tc_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)
clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_001_nl_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_001_nl_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_3 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)
clf_3.fit(x_1_train, y_3_train)


np.save('nn_ls_001_lr_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_001_lr_2',np.array(list(clf_2.coef_)))
np.save('nn_ls_001_lr_3',np.array(list(clf_3.coef_)))

# %%
network_twocompart = FeedForwardNetwork(2)
network_nonlinear = FeedForwardNetwork(2)
network_lorenz = FeedForwardNetwork(3)
T, Y = create_data_lorenz(p=0.25)
network_lorenz.load_weights('./NN_lorenz_checkpoints_025/my_checkpoint')
T, Y = create_data_nonlinear(p=0.25)
network_nonlinear.load_weights('./NN_nonlinear_checkpoints_025/my_checkpoint')
T, Y = create_data_twocompart(p=0.25)
network_twocompart.load_weights('./NN_twocompart_checkpoints_025/my_checkpoint')

T, Y = create_data_twocompart(p=0.25)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)



T, Y = create_data_nonlinear(p=0.25)
model = FeedForwardNetwork(2)
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)



T, Y = create_data_lorenz(p=0.25)
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_twocompart, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_025_tc_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_025_tc_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train  = obtain_twocompart_data(network_nonlinear, T)
clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)

np.save('nn_ls_025_nl_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_025_nl_2',np.array(list(clf_2.coef_)))

# %%
x_1_train, y_1_train, y_2_train, y_3_train  = obtain_twocompart_data(network_lorenz, T)

clf_1 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_2 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)
clf_3 = linear_model.LassoCV(alphas=[1.e-3, 1.e-2, 1.e-1, 1., 10, 100], max_iter=50000, fit_intercept=False)

clf_1.fit(x_1_train, y_1_train)
clf_2.fit(x_1_train, y_2_train)
clf_3.fit(x_1_train, y_3_train)


np.save('nn_ls_025_lr_1',np.array(list(clf_1.coef_)))
np.save('nn_ls_025_lr_2',np.array(list(clf_2.coef_)))
np.save('nn_ls_025_lr_3',np.array(list(clf_3.coef_)))
