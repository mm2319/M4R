# %%
import numpy as np
gpfd_ls_000_tc_1 = np.load("gpfd_ls_000_tc_1.npy")
gpfd_ls_000_tc_2 = np.load("gpfd_ls_000_tc_2.npy")
gpfd_ls_000_nl_1 = np.load("gpfd_ls_000_nl_1.npy")
gpfd_ls_000_nl_2 = np.load("gpfd_ls_000_nl_2.npy")
gpfd_ls_000_lr_1 = np.load("gpfd_ls_000_lr_1.npy")
gpfd_ls_000_lr_2 = np.load("gpfd_ls_000_lr_2.npy")
gpfd_ls_000_lr_3 = np.load("gpfd_ls_000_lr_3.npy")
gpfd_ls_000_tc_1 = np.load("gpfd_ls_001_tc_1.npy")
gpfd_ls_000_tc_2 = np.load("gpfd_ls_001_tc_2.npy")
gpfd_ls_000_nl_1 = np.load("gpfd_ls_001_nl_1.npy")
gpfd_ls_000_nl_2 = np.load("gpfd_ls_001_nl_2.npy")
gpfd_ls_000_lr_1 = np.load("gpfd_ls_001_lr_1.npy")
gpfd_ls_000_lr_2 = np.load("gpfd_ls_001_lr_2.npy")
gpfd_ls_000_lr_3 = np.load("gpfd_ls_001_lr_3.npy")
gpfd_ls_000_tc_1 = np.load("gpfd_ls_025_tc_1.npy")
gpfd_ls_000_tc_2 = np.load("gpfd_ls_025_tc_2.npy")
gpfd_ls_000_nl_1 = np.load("gpfd_ls_025_nl_1.npy")
gpfd_ls_000_nl_2 = np.load("gpfd_ls_025_nl_2.npy")
gpfd_ls_000_lr_1 = np.load("gpfd_ls_025_lr_1.npy")
gpfd_ls_000_lr_2 = np.load("gpfd_ls_025_lr_2.npy")
gpfd_ls_000_lr_3 = np.load("gpfd_ls_025_lr_3.npy")

gpfd_BR_CSS_000_tc_1 = np.load("gpfd_BR_CSS_000_tc_1.npy")[0][0]
gpfd_BR_CSS_000_tc_2 = np.load("gpfd_BR_CSS_000_tc_2.npy")[1][0]
gpfd_BR_CSS_000_nl_1 = np.load("gpfd_BR_CSS_000_nl_1.npy")[1][0]
gpfd_BR_CSS_000_nl_2 = np.load("gpfd_BR_CSS_000_nl_2.npy")[1][0]
gpfd_BR_CSS_000_lr_1 = np.load("gpfd_BR_CSS_000_lr_1.npy")[0][0]
gpfd_BR_CSS_000_lr_2 = np.load("gpfd_BR_CSS_000_lr_2.npy")[0][0]
gpfd_BR_CSS_000_lr_3 = np.load("gpfd_BR_CSS_000_lr_3.npy")[0][0]

gpfd_BR_CSS_001_tc_1 = np.load("gpfd_BR_CSS_001_tc_1.npy")[0][0]
gpfd_BR_CSS_001_tc_2 = np.load("gpfd_BR_CSS_001_tc_2.npy")[1][0]
gpfd_BR_CSS_001_nl_1 = np.load("gpfd_BR_CSS_001_nl_1.npy")[0][0]
gpfd_BR_CSS_001_nl_2 = np.load("gpfd_BR_CSS_001_nl_2.npy")[0][0]
gpfd_BR_CSS_001_lr_1 = np.load("gpfd_BR_CSS_001_lr_1.npy")[1][0]
gpfd_BR_CSS_001_lr_2 = np.load("gpfd_BR_CSS_001_lr_2.npy")[0][0]
gpfd_BR_CSS_001_lr_3 = np.load("gpfd_BR_CSS_001_lr_3.npy")[0][0]

gpfd_BR_CSS_025_tc_1 = np.load("gpfd_BR_CSS_025_tc_1.npy")[0][0]
gpfd_BR_CSS_025_tc_2 = np.load("gpfd_BR_CSS_025_tc_2.npy")[0][0]
gpfd_BR_CSS_025_nl_1 = np.load("gpfd_BR_CSS_025_nl_1.npy")[0][0]
gpfd_BR_CSS_025_nl_2 = np.load("gpfd_BR_CSS_025_nl_2.npy")[0][0]
gpfd_BR_CSS_025_lr_1 = np.load("gpfd_BR_CSS_025_lr_1.npy")[0][0]
gpfd_BR_CSS_025_lr_2 = np.load("gpfd_BR_CSS_025_lr_2.npy")[0][0]
gpfd_BR_CSS_025_lr_3 = np.load("gpfd_BR_CSS_025_lr_3.npy")[0][0]

gp_BR_CSS_000_tc_1 = np.load("gp_BR_CSS_000_tc_1.npy")[0][0]
gp_BR_CSS_000_tc_2 = np.load("gp_BR_CSS_000_tc_2.npy")[0][0]
gp_BR_CSS_000_nl_1 = np.load("gp_BR_CSS_000_nl_1.npy")[0][0]
gp_BR_CSS_000_nl_2 = np.load("gp_BR_CSS_000_nl_2.npy")[0][0]
gp_BR_CSS_000_lr_1 = np.load("gp_BR_CSS_000_lr_1.npy")[0][0]
gp_BR_CSS_000_lr_2 = np.load("gp_BR_CSS_000_lr_2.npy")[0][0]
gp_BR_CSS_000_lr_3 = np.load("gp_BR_CSS_000_lr_3.npy")[0][0]

gp_BR_CSS_001_tc_1 = np.load("gp_BR_CSS_001_tc_1.npy")[0][0]
gp_BR_CSS_001_tc_2 = np.load("gp_BR_CSS_001_tc_2.npy")[0][0]
gp_BR_CSS_001_nl_1 = np.load("gp_BR_CSS_001_nl_1.npy")[0][0]
gp_BR_CSS_001_nl_2 = np.load("gp_BR_CSS_001_nl_2.npy")[0][0]
gp_BR_CSS_001_lr_1 = np.load("gp_BR_CSS_001_lr_1.npy")[0][0]
gp_BR_CSS_001_lr_2 = np.load("gp_BR_CSS_001_lr_2.npy")[0][0]
gp_BR_CSS_001_lr_3 = np.load("gp_BR_CSS_001_lr_3.npy")[0][0]

gp_BR_CSS_025_tc_1 = np.load("gp_BR_CSS_025_tc_1.npy")[0][0]
gp_BR_CSS_025_tc_2 = np.load("gp_BR_CSS_025_tc_2.npy")[0][0]
gp_BR_CSS_025_nl_1 = np.load("gp_BR_CSS_025_nl_1.npy")[0][0]
gp_BR_CSS_025_nl_2 = np.load("gp_BR_CSS_025_nl_2.npy")[0][0]
gp_BR_CSS_025_lr_1 = np.load("gp_BR_CSS_025_lr_1.npy")[0][0]
gp_BR_CSS_025_lr_2 = np.load("gp_BR_CSS_025_lr_2.npy")[0][0]
gp_BR_CSS_025_lr_3 = np.load("gp_BR_CSS_025_lr_3.npy")[0][0]

gpfd_BR_DSS_000_tc_1 = np.load("gpfd_BR_DSS_000_tc_1.npy")[1][0]
gpfd_BR_DSS_000_tc_1_Z = np.load("gpfd_BR_DSS_000_tc_1_Z.npy")[1][0]
gpfd_BR_DSS_000_tc_2 = np.load("gpfd_BR_DSS_000_tc_2.npy")[0][0]
gpfd_BR_DSS_000_tc_2_Z = np.load("gpfd_BR_DSS_000_tc_2_Z.npy")[0][0]
gpfd_BR_DSS_000_nl_1 = np.load("gpfd_BR_DSS_000_nl_1.npy")[0][0]
gpfd_BR_DSS_000_nl_1_Z = np.load("gpfd_BR_DSS_000_nl_1_Z.npy")[0][0]
gpfd_BR_DSS_000_nl_2 = np.load("gpfd_BR_DSS_000_nl_2.npy")[1][0]
gpfd_BR_DSS_000_nl_2_Z = np.load("gpfd_BR_DSS_000_nl_2_Z.npy")[1][0]
gpfd_BR_DSS_000_lr_1 = np.load("gpfd_BR_DSS_000_lr_1.npy")[0][0]
gpfd_BR_DSS_000_lr_1_Z = np.load("gpfd_BR_DSS_000_lr_1_Z.npy")[0][0]
gpfd_BR_DSS_000_lr_2 = np.load("gpfd_BR_DSS_000_lr_2.npy")[1][0]
gpfd_BR_DSS_000_lr_2_Z = np.load("gpfd_BR_DSS_000_lr_2_Z.npy")[1][0]
gpfd_BR_DSS_000_lr_3 = np.load("gpfd_BR_DSS_000_lr_3.npy")[0][0]
gpfd_BR_DSS_000_lr_3_Z = np.load("gpfd_BR_DSS_000_lr_3_Z.npy")[0][0]

gpfd_BR_DSS_001_tc_1 = np.load("gpfd_BR_DSS_001_tc_1.npy")[0][0]
gpfd_BR_DSS_001_tc_1_Z = np.load("gpfd_BR_DSS_001_tc_1_Z.npy")[0][0]
gpfd_BR_DSS_001_tc_2 = np.load("gpfd_BR_DSS_001_tc_2.npy")[1][0]
gpfd_BR_DSS_001_tc_2_Z = np.load("gpfd_BR_DSS_001_tc_2_Z.npy")[1][0]
gpfd_BR_DSS_001_nl_1 = np.load("gpfd_BR_DSS_001_nl_1.npy")[0][0]
gpfd_BR_DSS_001_nl_1_Z = np.load("gpfd_BR_DSS_001_nl_1_Z.npy")[0][0]
gpfd_BR_DSS_001_nl_2 = np.load("gpfd_BR_DSS_001_nl_2.npy")[0][0]
gpfd_BR_DSS_001_nl_2_Z = np.load("gpfd_BR_DSS_001_nl_2_Z.npy")[0][0]
gpfd_BR_DSS_001_lr_1 = np.load("gpfd_BR_DSS_001_lr_1.npy")[0][0]
gpfd_BR_DSS_001_lr_1_Z = np.load("gpfd_BR_DSS_001_lr_1_Z.npy")[0][0]
gpfd_BR_DSS_001_lr_2 = np.load("gpfd_BR_DSS_001_lr_2.npy")[0][0]
gpfd_BR_DSS_001_lr_2_Z = np.load("gpfd_BR_DSS_001_lr_2_Z.npy")[0][0]
gpfd_BR_DSS_001_lr_3 = np.load("gpfd_BR_DSS_001_lr_3.npy")[0][0]
gpfd_BR_DSS_001_lr_3_Z = np.load("gpfd_BR_DSS_001_lr_3_Z.npy")[0][0]

gpfd_BR_DSS_025_tc_1 = np.load("gpfd_BR_DSS_025_tc_1.npy")[1][0]
gpfd_BR_DSS_025_tc_1_Z = np.load("gpfd_BR_DSS_025_tc_1_Z.npy")[1][0]
gpfd_BR_DSS_025_tc_2 = np.load("gpfd_BR_DSS_025_tc_2.npy")[1][0]
gpfd_BR_DSS_025_tc_2_Z = np.load("gpfd_BR_DSS_025_tc_2_Z.npy")[1][0]
gpfd_BR_DSS_025_nl_1 = np.load("gpfd_BR_DSS_025_nl_1.npy")[1][0]
gpfd_BR_DSS_025_nl_1_Z = np.load("gpfd_BR_DSS_025_nl_1_Z.npy")[1][0]
gpfd_BR_DSS_025_nl_2 = np.load("gpfd_BR_DSS_025_nl_2.npy")[0][0]
gpfd_BR_DSS_025_nl_2_Z = np.load("gpfd_BR_DSS_025_nl_2_Z.npy")[0][0]
gpfd_BR_DSS_025_lr_1 = np.load("gpfd_BR_DSS_025_lr_1.npy")[0][0]
gpfd_BR_DSS_025_lr_1_Z = np.load("gpfd_BR_DSS_025_lr_1_Z.npy")[0][0]
gpfd_BR_DSS_025_lr_2 = np.load("gpfd_BR_DSS_025_lr_2.npy")[0][0]
gpfd_BR_DSS_025_lr_2_Z = np.load("gpfd_BR_DSS_025_lr_2_Z.npy")[0][0]
gpfd_BR_DSS_025_lr_3 = np.load("gpfd_BR_DSS_025_lr_3.npy")[1][0]
gpfd_BR_DSS_025_lr_3_Z = np.load("gpfd_BR_DSS_025_lr_3_Z.npy")[1][0]

gpfd_BR_MDSS_000_tc_1 = np.load("gpfd_BR_MDSS_000_tc_1.npy")[0][0]
gpfd_BR_MDSS_000_tc_1_Z = np.load("gpfd_BR_MDSS_000_tc_1_Z.npy")[0][0]
gpfd_BR_MDSS_000_tc_2 = np.load("gpfd_BR_MDSS_000_tc_2.npy")[0][0]
gpfd_BR_MDSS_000_tc_2_Z = np.load("gpfd_BR_MDSS_000_tc_2_Z.npy")[0][0]
gpfd_BR_MDSS_000_nl_1 = np.load("gpfd_BR_MDSS_000_nl_1.npy")[0][0]
gpfd_BR_MDSS_000_nl_1_Z = np.load("gpfd_BR_MDSS_000_nl_1_Z.npy")[0][0]
gpfd_BR_MDSS_000_nl_2 = np.load("gpfd_BR_MDSS_000_nl_2.npy")[0][0]
gpfd_BR_MDSS_000_nl_2_Z = np.load("gpfd_BR_MDSS_000_nl_2_Z.npy")[0][0]
gpfd_BR_MDSS_000_lr_1 = np.load("gpfd_BR_MDSS_000_lr_1.npy")[0][0]
gpfd_BR_MDSS_000_lr_1_Z = np.load("gpfd_BR_MDSS_000_lr_1_Z.npy")[0][0]
gpfd_BR_MDSS_000_lr_2 = np.load("gpfd_BR_MDSS_000_lr_2.npy")[0][0]
gpfd_BR_MDSS_000_lr_2_Z = np.load("gpfd_BR_MDSS_000_lr_2_Z.npy")[0][0]
gpfd_BR_MDSS_000_lr_3 = np.load("gpfd_BR_MDSS_000_lr_3.npy")[1][0]
gpfd_BR_MDSS_000_lr_3_Z = np.load("gpfd_BR_MDSS_000_lr_3_Z.npy")[1][0]

gpfd_BR_MDSS_001_tc_1 = np.load("gpfd_BR_MDSS_001_tc_1.npy")[0][0]
gpfd_BR_MDSS_001_tc_1_Z = np.load("gpfd_BR_MDSS_001_tc_1_Z.npy")[0][0]
gpfd_BR_MDSS_001_tc_2 = np.load("gpfd_BR_MDSS_001_tc_2.npy")[0][0]
gpfd_BR_MDSS_001_tc_2_Z = np.load("gpfd_BR_MDSS_001_tc_2_Z.npy")[0][0]
gpfd_BR_MDSS_001_nl_1 = np.load("gpfd_BR_MDSS_001_nl_1.npy")[0][0]
gpfd_BR_MDSS_001_nl_1_Z = np.load("gpfd_BR_MDSS_001_nl_1_Z.npy")[0][0]
gpfd_BR_MDSS_001_nl_2 = np.load("gpfd_BR_MDSS_001_nl_2.npy")[1][0]
gpfd_BR_MDSS_001_nl_2_Z = np.load("gpfd_BR_MDSS_001_nl_2_Z.npy")[1][0]
gpfd_BR_MDSS_001_lr_1 = np.load("gpfd_BR_MDSS_001_lr_1.npy")[1][0]
gpfd_BR_MDSS_001_lr_1_Z = np.load("gpfd_BR_MDSS_001_lr_1_Z.npy")[1][0]
gpfd_BR_MDSS_001_lr_2 = np.load("gpfd_BR_MDSS_001_lr_2.npy")[1][0]
gpfd_BR_MDSS_001_lr_2_Z = np.load("gpfd_BR_MDSS_001_lr_2_Z.npy")[1][0]
gpfd_BR_MDSS_001_lr_3 = np.load("gpfd_BR_MDSS_001_lr_3.npy")[1][0]
gpfd_BR_MDSS_001_lr_3_Z = np.load("gpfd_BR_MDSS_001_lr_3_Z.npy")[1][0]

gpfd_BR_MDSS_025_tc_1 = np.load("gpfd_BR_MDSS_025_tc_1.npy")[1][0]
gpfd_BR_MDSS_025_tc_1_Z = np.load("gpfd_BR_MDSS_025_tc_1_Z.npy")[1][0]
gpfd_BR_MDSS_025_tc_2 = np.load("gpfd_BR_MDSS_025_tc_2.npy")[0][0]
gpfd_BR_MDSS_025_tc_2_Z = np.load("gpfd_BR_MDSS_025_tc_2_Z.npy")[0][0]
gpfd_BR_MDSS_025_nl_1 = np.load("gpfd_BR_MDSS_025_nl_1.npy")[1][0]
gpfd_BR_MDSS_025_nl_1_Z = np.load("gpfd_BR_MDSS_025_nl_1_Z.npy")[1][0]
gpfd_BR_MDSS_025_nl_2 = np.load("gpfd_BR_MDSS_025_nl_2.npy")[0][0]
gpfd_BR_MDSS_025_nl_2_Z = np.load("gpfd_BR_MDSS_025_nl_2_Z.npy")[0][0]
gpfd_BR_MDSS_025_lr_1 = np.load("gpfd_BR_MDSS_025_lr_1.npy")[0][0]
gpfd_BR_MDSS_025_lr_1_Z = np.load("gpfd_BR_MDSS_025_lr_1_Z.npy")[0][0]
gpfd_BR_MDSS_025_lr_2 = np.load("gpfd_BR_MDSS_025_lr_2.npy")[0][0]
gpfd_BR_MDSS_025_lr_2_Z = np.load("gpfd_BR_MDSS_025_lr_2_Z.npy")[0][0]
gpfd_BR_MDSS_025_lr_3 = np.load("gpfd_BR_MDSS_025_lr_3.npy")[1][0]
gpfd_BR_MDSS_025_lr_3_Z = np.load("gpfd_BR_MDSS_025_lr_3_Z.npy")[1][0]

gp_BR_DSS_000_tc_1 = np.load("gp_BR_DSS_000_tc_1.npy")
gp_BR_DSS_000_tc_1_Z = np.load("gp_BR_DSS_000_tc_1_Z.npy")
gp_BR_DSS_000_tc_2 = np.load("gp_BR_DSS_000_tc_2.npy")
gp_BR_DSS_000_tc_2_Z = np.load("gp_BR_DSS_000_tc_2_Z.npy")
gp_BR_DSS_000_nl_1 = np.load("gp_BR_DSS_000_nl_1.npy")
gp_BR_DSS_000_nl_1_Z = np.load("gp_BR_DSS_000_nl_1_Z.npy")
gp_BR_DSS_000_nl_2 = np.load("gp_BR_DSS_000_nl_2.npy")
gp_BR_DSS_000_nl_2_Z = np.load("gp_BR_DSS_000_nl_2_Z.npy")
gp_BR_DSS_000_lr_1 = np.load("gp_BR_DSS_000_lr_1.npy")
gp_BR_DSS_000_lr_1_Z = np.load("gp_BR_DSS_000_lr_1_Z.npy")
gp_BR_DSS_000_lr_2 = np.load("gp_BR_DSS_000_lr_2.npy")
gp_BR_DSS_000_lr_2_Z = np.load("gp_BR_DSS_000_lr_2_Z.npy")
gp_BR_DSS_000_lr_3 = np.load("gp_BR_DSS_000_lr_3.npy")
gp_BR_DSS_000_lr_3_Z = np.load("gp_BR_DSS_000_lr_3_Z.npy")

gp_BR_DSS_001_tc_1 = np.load("gp_BR_DSS_001_tc_1.npy")
gp_BR_DSS_001_tc_1_Z = np.load("gp_BR_DSS_001_tc_1_Z.npy")
gp_BR_DSS_001_tc_2 = np.load("gp_BR_DSS_001_tc_2.npy")
gp_BR_DSS_001_tc_2_Z = np.load("gp_BR_DSS_001_tc_2_Z.npy")
gp_BR_DSS_001_nl_1 = np.load("gp_BR_DSS_001_nl_1.npy")
gp_BR_DSS_001_nl_1_Z = np.load("gp_BR_DSS_001_nl_1_Z.npy")
gp_BR_DSS_001_nl_2 = np.load("gp_BR_DSS_001_nl_2.npy")
gp_BR_DSS_001_nl_2_Z = np.load("gp_BR_DSS_001_nl_2_Z.npy")
gp_BR_DSS_001_lr_1 = np.load("gp_BR_DSS_001_lr_1.npy")
gp_BR_DSS_001_lr_1_Z = np.load("gp_BR_DSS_001_lr_1_Z.npy")
gp_BR_DSS_001_lr_2 = np.load("gp_BR_DSS_001_lr_2.npy")
gp_BR_DSS_001_lr_2_Z = np.load("gp_BR_DSS_001_lr_2_Z.npy")
gp_BR_DSS_001_lr_3 = np.load("gp_BR_DSS_001_lr_3.npy")
gp_BR_DSS_001_lr_3_Z = np.load("gp_BR_DSS_001_lr_3_Z.npy")

gp_BR_DSS_025_tc_1 = np.load("gp_BR_DSS_025_tc_1.npy")
gp_BR_DSS_025_tc_1_Z = np.load("gp_BR_DSS_025_tc_1_Z.npy")
gp_BR_DSS_025_tc_2 = np.load("gp_BR_DSS_025_tc_2.npy")
gp_BR_DSS_025_tc_2_Z = np.load("gp_BR_DSS_025_tc_2_Z.npy")
gp_BR_DSS_025_nl_1 = np.load("gp_BR_DSS_025_nl_1.npy")
gp_BR_DSS_025_nl_1_Z = np.load("gp_BR_DSS_025_nl_1_Z.npy")
gp_BR_DSS_025_nl_2 = np.load("gp_BR_DSS_025_nl_2.npy")
gp_BR_DSS_025_nl_2_Z = np.load("gp_BR_DSS_025_nl_2_Z.npy")
gp_BR_DSS_025_lr_1 = np.load("gp_BR_DSS_025_lr_1.npy")
gp_BR_DSS_025_lr_1_Z = np.load("gp_BR_DSS_025_lr_1_Z.npy")
gp_BR_DSS_025_lr_2 = np.load("gp_BR_DSS_025_lr_2.npy")
gp_BR_DSS_025_lr_2_Z = np.load("gp_BR_DSS_025_lr_2_Z.npy")
gp_BR_DSS_025_lr_3 = np.load("gp_BR_DSS_025_lr_3.npy")
gp_BR_DSS_025_lr_3_Z = np.load("gp_BR_DSS_025_lr_3_Z.npy")

gp_BR_MDSS_000_tc_1 = np.load("gp_BR_MDSS_000_tc_1.npy")
gp_BR_MDSS_000_tc_1_Z = np.load("gp_BR_MDSS_000_tc_1_Z.npy")
gp_BR_MDSS_000_tc_2 = np.load("gp_BR_MDSS_000_tc_2.npy")
gp_BR_MDSS_000_tc_2_Z = np.load("gp_BR_MDSS_000_tc_2_Z.npy")
gp_BR_MDSS_000_nl_1 = np.load("gp_BR_MDSS_000_nl_1.npy")
gp_BR_MDSS_000_nl_1_Z = np.load("gp_BR_MDSS_000_nl_1_Z.npy")
gp_BR_MDSS_000_nl_2 = np.load("gp_BR_MDSS_000_nl_2.npy")
gp_BR_MDSS_000_nl_2_Z = np.load("gp_BR_MDSS_000_nl_2_Z.npy")
gp_BR_MDSS_000_lr_1 = np.load("gp_BR_MDSS_000_lr_1.npy")
gp_BR_MDSS_000_lr_1_Z = np.load("gp_BR_MDSS_000_lr_1_Z.npy")
gp_BR_MDSS_000_lr_2 = np.load("gp_BR_MDSS_000_lr_2.npy")
gp_BR_MDSS_000_lr_2_Z = np.load("gp_BR_MDSS_000_lr_2_Z.npy")
gp_BR_MDSS_000_lr_3 = np.load("gp_BR_MDSS_000_lr_3.npy")
gp_BR_MDSS_000_lr_3_Z = np.load("gp_BR_MDSS_000_lr_3_Z.npy")

gp_BR_MDSS_001_tc_1 = np.load("gp_BR_MDSS_001_tc_1.npy")
gp_BR_MDSS_001_tc_1_Z = np.load("gp_BR_MDSS_001_tc_1_Z.npy")
gp_BR_MDSS_001_tc_2 = np.load("gp_BR_MDSS_001_tc_2.npy")
gp_BR_MDSS_001_tc_2_Z = np.load("gp_BR_MDSS_001_tc_2_Z.npy")
gp_BR_MDSS_001_nl_1 = np.load("gp_BR_MDSS_001_nl_1.npy")
gp_BR_MDSS_001_nl_1_Z = np.load("gp_BR_MDSS_001_nl_1_Z.npy")
gp_BR_MDSS_001_nl_2 = np.load("gp_BR_MDSS_001_nl_2.npy")
gp_BR_MDSS_001_nl_2_Z = np.load("gp_BR_MDSS_001_nl_2_Z.npy")
gp_BR_MDSS_001_lr_1 = np.load("gp_BR_MDSS_001_lr_1.npy")
gp_BR_MDSS_001_lr_1_Z = np.load("gp_BR_MDSS_001_lr_1_Z.npy")
gp_BR_MDSS_001_lr_2 = np.load("gp_BR_MDSS_001_lr_2.npy")
gp_BR_MDSS_001_lr_2_Z = np.load("gp_BR_MDSS_001_lr_2_Z.npy")
gp_BR_MDSS_001_lr_3 = np.load("gp_BR_MDSS_001_lr_3.npy")
gp_BR_MDSS_001_lr_3_Z = np.load("gp_BR_MDSS_001_lr_3_Z.npy")

gp_BR_MDSS_025_tc_1 = np.load("gp_BR_MDSS_025_tc_1.npy")
gp_BR_MDSS_025_tc_1_Z = np.load("gp_BR_MDSS_025_tc_1_Z.npy")
gp_BR_MDSS_025_tc_2 = np.load("gp_BR_MDSS_025_tc_2.npy")
gp_BR_MDSS_025_tc_2_Z = np.load("gp_BR_MDSS_025_tc_2_Z.npy")
gp_BR_MDSS_025_nl_1 = np.load("gp_BR_MDSS_025_nl_1.npy")
gp_BR_MDSS_025_nl_1_Z = np.load("gp_BR_MDSS_025_nl_1_Z.npy")
gp_BR_MDSS_025_nl_2 = np.load("gp_BR_MDSS_025_nl_2.npy")
gp_BR_MDSS_025_nl_2_Z = np.load("gp_BR_MDSS_025_nl_2_Z.npy")
gp_BR_MDSS_025_lr_1 = np.load("gp_BR_MDSS_025_lr_1.npy")
gp_BR_MDSS_025_lr_1_Z = np.load("gp_BR_MDSS_025_lr_1_Z.npy")
gp_BR_MDSS_025_lr_2 = np.load("gp_BR_MDSS_025_lr_2.npy")
gp_BR_MDSS_025_lr_2_Z = np.load("gp_BR_MDSS_025_lr_2_Z.npy")
gp_BR_MDSS_025_lr_3 = np.load("gp_BR_MDSS_025_lr_3.npy")
gp_BR_MDSS_025_lr_3_Z = np.load("gp_BR_MDSS_025_lr_3_Z.npy")

# %%
nn_BR_CSS_000_tc_1 = np.load("nn_BR_CSS_000_tc_1.npy")
nn_BR_CSS_000_tc_2 = np.load("nn_BR_CSS_000_tc_2.npy")
nn_BR_CSS_000_nl_1 = np.load("nn_BR_CSS_000_nl_1.npy")
nn_BR_CSS_000_nl_2 = np.load("nn_BR_CSS_000_nl_2.npy")
nn_BR_CSS_000_lr_1 = np.load("nn_BR_CSS_000_lr_1.npy")
nn_BR_CSS_000_lr_2 = np.load("nn_BR_CSS_000_lr_2.npy")
nn_BR_CSS_000_lr_3 = np.load("nn_BR_CSS_000_lr_3.npy")

nn_BR_CSS_001_tc_1 = np.load("nn_BR_CSS_001_tc_1.npy")
nn_BR_CSS_001_tc_2 = np.load("nn_BR_CSS_001_tc_2.npy")
nn_BR_CSS_001_nl_1 = np.load("nn_BR_CSS_001_nl_1.npy")
nn_BR_CSS_001_nl_2 = np.load("nn_BR_CSS_001_nl_2.npy")
nn_BR_CSS_001_lr_1 = np.load("nn_BR_CSS_001_lr_1.npy")
nn_BR_CSS_001_lr_2 = np.load("nn_BR_CSS_001_lr_2.npy")
nn_BR_CSS_001_lr_3 = np.load("nn_BR_CSS_001_lr_3.npy")

nn_BR_CSS_025_tc_1 = np.load("nn_BR_CSS_025_tc_1.npy")
nn_BR_CSS_025_tc_2 = np.load("nn_BR_CSS_025_tc_2.npy")
nn_BR_CSS_025_nl_1 = np.load("nn_BR_CSS_025_nl_1.npy")
nn_BR_CSS_025_nl_2 = np.load("nn_BR_CSS_025_nl_2.npy")
nn_BR_CSS_025_lr_1 = np.load("nn_BR_CSS_025_lr_1.npy")
nn_BR_CSS_025_lr_2 = np.load("nn_BR_CSS_025_lr_2.npy")
nn_BR_CSS_025_lr_3 = np.load("nn_BR_CSS_025_lr_3.npy")


nn_BR_DSS_000_tc_1 = np.load("nn_BR_DSS_000_tc_1.npy")
nn_BR_DSS_000_tc_1_Z = np.load("nn_BR_DSS_000_tc_1_Z.npy")
nn_BR_DSS_000_tc_2 = np.load("nn_BR_DSS_000_tc_2.npy")
nn_BR_DSS_000_tc_2_Z = np.load("nn_BR_DSS_000_tc_2_Z.npy")
nn_BR_DSS_000_nl_1 = np.load("nn_BR_DSS_000_nl_1.npy")
nn_BR_DSS_000_nl_1_Z = np.load("nn_BR_DSS_000_nl_1_Z.npy")
nn_BR_DSS_000_nl_2 = np.load("nn_BR_DSS_000_nl_2.npy")
nn_BR_DSS_000_nl_2_Z = np.load("nn_BR_DSS_000_nl_2_Z.npy")
nn_BR_DSS_000_lr_1 = np.load("nn_BR_DSS_000_lr_1.npy")
nn_BR_DSS_000_lr_1_Z = np.load("nn_BR_DSS_000_lr_1_Z.npy")
nn_BR_DSS_000_lr_2 = np.load("nn_BR_DSS_000_lr_2.npy")
nn_BR_DSS_000_lr_2_Z = np.load("nn_BR_DSS_000_lr_2_Z.npy")
nn_BR_DSS_000_lr_3 = np.load("nn_BR_DSS_000_lr_3.npy")
nn_BR_DSS_000_lr_3_Z = np.load("nn_BR_DSS_000_lr_3_Z.npy")

nn_BR_DSS_001_tc_1 = np.load("nn_BR_DSS_001_tc_1.npy")
nn_BR_DSS_001_tc_1_Z = np.load("nn_BR_DSS_001_tc_1_Z.npy")
nn_BR_DSS_001_tc_2 = np.load("nn_BR_DSS_001_tc_2.npy")
nn_BR_DSS_001_tc_2_Z = np.load("nn_BR_DSS_001_tc_2_Z.npy")
nn_BR_DSS_001_nl_1 = np.load("nn_BR_DSS_001_nl_1.npy")
nn_BR_DSS_001_nl_1_Z = np.load("nn_BR_DSS_001_nl_1_Z.npy")
nn_BR_DSS_001_nl_2 = np.load("nn_BR_DSS_001_nl_2.npy")
nn_BR_DSS_001_nl_2_Z = np.load("nn_BR_DSS_001_nl_2_Z.npy")
nn_BR_DSS_001_lr_1 = np.load("nn_BR_DSS_001_lr_1.npy")
nn_BR_DSS_001_lr_1_Z = np.load("nn_BR_DSS_001_lr_1_Z.npy")
nn_BR_DSS_001_lr_2 = np.load("nn_BR_DSS_001_lr_2.npy")
nn_BR_DSS_001_lr_2_Z = np.load("nn_BR_DSS_001_lr_2_Z.npy")
nn_BR_DSS_001_lr_3 = np.load("nn_BR_DSS_001_lr_3.npy")
nn_BR_DSS_001_lr_3_Z = np.load("nn_BR_DSS_001_lr_3_Z.npy")

nn_BR_DSS_025_tc_1 = np.load("nn_BR_DSS_025_tc_1.npy")
nn_BR_DSS_025_tc_1_Z = np.load("nn_BR_DSS_025_tc_1_Z.npy")
nn_BR_DSS_025_tc_2 = np.load("nn_BR_DSS_025_tc_2.npy")
nn_BR_DSS_025_tc_2_Z = np.load("nn_BR_DSS_025_tc_2_Z.npy")
nn_BR_DSS_025_nl_1 = np.load("nn_BR_DSS_025_nl_1.npy")
nn_BR_DSS_025_nl_1_Z = np.load("nn_BR_DSS_025_nl_1_Z.npy")
nn_BR_DSS_025_nl_2 = np.load("nn_BR_DSS_025_nl_2.npy")
nn_BR_DSS_025_nl_2_Z = np.load("nn_BR_DSS_025_nl_2_Z.npy")
nn_BR_DSS_025_lr_1 = np.load("nn_BR_DSS_025_lr_1.npy")
nn_BR_DSS_025_lr_1_Z = np.load("nn_BR_DSS_025_lr_1_Z.npy")
nn_BR_DSS_025_lr_2 = np.load("nn_BR_DSS_025_lr_2.npy")
nn_BR_DSS_025_lr_2_Z = np.load("nn_BR_DSS_025_lr_2_Z.npy")
nn_BR_DSS_025_lr_3 = np.load("nn_BR_DSS_025_lr_3.npy")
nn_BR_DSS_025_lr_3_Z = np.load("nn_BR_DSS_025_lr_3_Z.npy")

nn_BR_MDSS_000_tc_1 = np.load("nn_BR_MDSS_000_tc_1.npy")
nn_BR_MDSS_000_tc_1_Z = np.load("nn_BR_MDSS_000_tc_1_Z.npy")
nn_BR_MDSS_000_tc_2 = np.load("nn_BR_MDSS_000_tc_2.npy")
nn_BR_MDSS_000_tc_2_Z = np.load("nn_BR_MDSS_000_tc_2_Z.npy")
nn_BR_MDSS_000_nl_1 = np.load("nn_BR_MDSS_000_nl_1.npy")
nn_BR_MDSS_000_nl_1_Z = np.load("nn_BR_MDSS_000_nl_1_Z.npy")
nn_BR_MDSS_000_nl_2 = np.load("nn_BR_MDSS_000_nl_2.npy")
nn_BR_MDSS_000_nl_2_Z = np.load("nn_BR_MDSS_000_nl_2_Z.npy")
nn_BR_MDSS_000_lr_1 = np.load("nn_BR_MDSS_000_lr_1.npy")
nn_BR_MDSS_000_lr_1_Z = np.load("nn_BR_MDSS_000_lr_1_Z.npy")
nn_BR_MDSS_000_lr_2 = np.load("nn_BR_MDSS_000_lr_2.npy")
nn_BR_MDSS_000_lr_2_Z = np.load("nn_BR_MDSS_000_lr_2_Z.npy")
nn_BR_MDSS_000_lr_3 = np.load("nn_BR_MDSS_000_lr_3.npy")
nn_BR_MDSS_000_lr_3_Z = np.load("nn_BR_MDSS_000_lr_3_Z.npy")

nn_BR_MDSS_001_tc_1 = np.load("nn_BR_MDSS_001_tc_1.npy")
nn_BR_MDSS_001_tc_1_Z = np.load("nn_BR_MDSS_001_tc_1_Z.npy")
nn_BR_MDSS_001_tc_2 = np.load("nn_BR_MDSS_001_tc_2.npy")
nn_BR_MDSS_001_tc_2_Z = np.load("nn_BR_MDSS_001_tc_2_Z.npy")
nn_BR_MDSS_001_nl_1 = np.load("nn_BR_MDSS_001_nl_1.npy")
nn_BR_MDSS_001_nl_1_Z = np.load("nn_BR_MDSS_001_nl_1_Z.npy")
nn_BR_MDSS_001_nl_2 = np.load("nn_BR_MDSS_001_nl_2.npy")
nn_BR_MDSS_001_nl_2_Z = np.load("nn_BR_MDSS_001_nl_2_Z.npy")
nn_BR_MDSS_001_lr_1 = np.load("nn_BR_MDSS_001_lr_1.npy")
nn_BR_MDSS_001_lr_1_Z = np.load("nn_BR_MDSS_001_lr_1_Z.npy")
nn_BR_MDSS_001_lr_2 = np.load("nn_BR_MDSS_001_lr_2.npy")
nn_BR_MDSS_001_lr_2_Z = np.load("nn_BR_MDSS_001_lr_2_Z.npy")
nn_BR_MDSS_001_lr_3 = np.load("nn_BR_MDSS_001_lr_3.npy")
nn_BR_MDSS_001_lr_3_Z = np.load("nn_BR_MDSS_001_lr_3_Z.npy")

nn_BR_MDSS_025_tc_1 = np.load("nn_BR_MDSS_025_tc_1.npy")
nn_BR_MDSS_025_tc_1_Z = np.load("nn_BR_MDSS_025_tc_1_Z.npy")
nn_BR_MDSS_025_tc_2 = np.load("nn_BR_MDSS_025_tc_2.npy")
nn_BR_MDSS_025_tc_2_Z = np.load("nn_BR_MDSS_025_tc_2_Z.npy")
nn_BR_MDSS_025_nl_1 = np.load("nn_BR_MDSS_025_nl_1.npy")
nn_BR_MDSS_025_nl_1_Z = np.load("nn_BR_MDSS_025_nl_1_Z.npy")
nn_BR_MDSS_025_nl_2 = np.load("nn_BR_MDSS_025_nl_2.npy")
nn_BR_MDSS_025_nl_2_Z = np.load("nn_BR_MDSS_025_nl_2_Z.npy")
nn_BR_MDSS_025_lr_1 = np.load("nn_BR_MDSS_025_lr_1.npy")
nn_BR_MDSS_025_lr_1_Z = np.load("nn_BR_MDSS_025_lr_1_Z.npy")
nn_BR_MDSS_025_lr_2 = np.load("nn_BR_MDSS_025_lr_2.npy")
nn_BR_MDSS_025_lr_2_Z = np.load("nn_BR_MDSS_025_lr_2_Z.npy")
nn_BR_MDSS_025_lr_3 = np.load("nn_BR_MDSS_025_lr_3.npy")
nn_BR_MDSS_025_lr_3_Z = np.load("nn_BR_MDSS_025_lr_3_Z.npy")

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_tc_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_tc_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_tc_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_tc_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_tc_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_tc_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_tc_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_tc_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_tc_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_tc_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_tc_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_tc_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_nl_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_nl_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_nl_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_nl_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_nl_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_nl_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_nl_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_nl_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_nl_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_nl_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_nl_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_nl_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_lr_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_lr_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_lr_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_lr_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_lr_1'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_lr_1_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_lr_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_lr_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_lr_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_lr_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_lr_2'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_lr_2_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '000_lr_3'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '000_lr_3_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '001_lr_3'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '001_lr_3_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))

# %%
import numpy as np

# we want to get all np.array objects with name 'arr_name'
name = '025_lr_3'

# first, get all variables in the global scope
global_vars = globals()

# then, filter the variables by name
p = '025_lr_3_Z'
target_dict = {var_name: var for var_name, var in global_vars.items() 
               if var_name.endswith(name) and (isinstance(var, np.ndarray) or isinstance(var, list))}
# now, target_vars contains all np.array objects with the specified name
dict = {}
# &FL&FC&FD&FM&SL&SC&SD&SM&F'L&F'C&F'D&F'M&S'L&S'C&S'D&S'M
p_dict = {}
for var_name, var in global_vars.items():
    if var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] =np.array(var)
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(p):
            p_dict[var_name] = np.array(var)  

for var_name, var in global_vars.items():
    if var_name.startswith("gp_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gp_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = np.array(var)
    elif var_name.startswith("gp_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gp_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gp_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("gpfd_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("gpfd_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "gpfd_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_ls"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_CSS"):
        if var_name.endswith(name):
            dict[var_name] = var
    elif var_name.startswith("nn_BR_DSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_DSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p
    elif var_name.startswith("nn_BR_MDSS"):
        if var_name.endswith(name):
            for i in p_dict.keys():
                if  "nn_BR_MDSS" in i:
                    p = p_dict[i]
            dict[var_name] = np.array(var)*p



print(dict.keys())
# Get the length of the lists
list_length = len(next(iter(dict.values())))

# Loop over the length of the lists
for i in range(list_length):
    # For each key, get the i-th element of the list and add it to a list
    elements = [float('%.2g'%values[i]) for values in dict.values()]
    elements = list(map(str, elements))
    
    # Join the elements with "&" and print
    print(" & ".join(elements))
